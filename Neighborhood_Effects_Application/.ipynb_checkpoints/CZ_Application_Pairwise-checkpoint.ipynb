# %%
import numpy as np
import pandas as pd
from itertools import product
import matplotlib.pyplot as plt
import scipy as scp
import multiprocessing
# Out:
# /Users/andpetrouzeniou/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
def c_quantile(a, Sigma_Y, n_iter, rand):

    N = len(Sigma_Y)
    
    draws = rand.multivariate_normal(np.zeros(N), Sigma_Y, n_iter)
    n_draws = -1 * draws
    
    lst = []
    
    for i in range(len(draws)):
        
        draw = draws[i]
        
        comps = []
        
        for row in range(len(draw)):
            for col in range(len(draw)):
                comps.append(abs(draw[row] - draw[col]) / (Sigma_Y[row, row] + Sigma_Y[col,col]) ** 0.5)
        
        lst.append(np.max(np.array(comps)))

    return np.quantile(np.array(lst), a)

# %%
def d_quantile(b, k, Sigma_X, n_iter, rand):

    N = len(Sigma_X)
    
    draws = rand.multivariate_normal(np.zeros(N), Sigma_X, n_iter)
    lst = [] # np.amax(draws, axis=1) - np.amax((-1 * draws), axis=1)
    
    for i in range(len(draws)):
        
        draw = draws[i]
        
        comps = []
        
        for row in range(len(draw)):
            for col in range(len(draw)):
                if draw[row] - draw[col] > 0:
                    comps.append(abs(draw[row] - draw[col]) / (Sigma_X[row, row] + Sigma_X[col,col] - 2 * Sigma_X[row,col]) ** 0.5)
        
        lst.append(np.max(np.array(comps)))

    return np.quantile(np.array(lst), b)

# %%
def make_I_list(rank_list, X_temp, delta_L, delta_U):
    
    rank = np.max(np.array(rank_list))
    
    # need matrix A[i,j] = X_temp[j] + delta_L[j,i]
    
    X_temp_mat = np.tile(X_temp, (len(X_temp), 1))
    A = X_temp_mat + np.transpose(delta_L)
    
    np.fill_diagonal(A, np.nan)
    A = A[~np.isnan(A)].reshape(A.shape[0], A.shape[1] - 1)

    row_ranks = np.partition(A, -rank, axis=1)[:, -rank]
    
    indices = np.where(X_temp >= row_ranks, 1, 0)
        
    return indices

# %%
def iteration_function(l):
    
    Sigma, rank_list, delta_L, delta_U, Sigma_Y, random_ng = l[0], l[1], l[2], l[3], l[4], l[5]
    
    draw = random_ng.multivariate_normal(np.zeros(len(Sigma)), Sigma)

    X_temp = draw.copy()
    rank = np.max(np.array(rank_list))

    I_list = make_I_list(rank_list, X_temp, delta_L, delta_U)

    I_indices = np.where(I_list == 1)[0]  

    return(np.max((abs(X_temp) / (np.diagonal(Sigma_Y) ** 0.5))[I_indices]))

# %%
def iteration_function_asymmetric(l):
    
    Sigma, rank_list, delta_L, delta_U, Sigma_Y, random_ng = l[0], l[1], l[2], l[3], l[4], l[5]
    
    draw = random_ng.multivariate_normal(np.zeros(len(Sigma)), Sigma)

    X_temp = draw.copy()
    rank = np.max(np.array(rank_list))

    I_list = make_I_list(rank_list, X_temp, delta_L, delta_U)

    I_indices = np.where(I_list == 1)[0]  

    return(np.max(((X_temp) / (np.diagonal(Sigma_Y) ** 0.5))[I_indices]), 
              np.min(((X_temp) / (np.diagonal(Sigma_Y) ** 0.5))[I_indices]))

# %%
def c_2_quantile(ab, rank_list_top, rank_list_bottom, Sigma, delta_L, delta_U, n_iter, rand):

    lst = []

    Sigma_Y = Sigma
    
    print(len(Sigma_Y))

    for a in range(n_iter):
        print(a, end="")
        # print(i, end="")
        draw = rand.multivariate_normal(np.zeros(len(Sigma)), Sigma)
            
        X_temp = draw.copy()

        I_list_top = make_I_list(rank_list_top, X_temp, delta_L, delta_U)
        I_list_bot = make_I_list(rank_list_bottom, (-1 * X_temp), np.transpose(delta_L), np.transpose(delta_U))
        
        I_indices_top = np.where(I_list_top == 1)[0]    
        I_indices_bot = np.where(I_list_bot == 1)[0]  

        tops = X_temp[I_indices_top]
        bots = X_temp[I_indices_bot]
        
        print()
        print(len(tops))
        print(len(bots))
        
        tops2 = np.tile(tops, (len(bots), 1)) # len(bots) length, len(tops) width
        bots2 = np.transpose(np.tile(bots, (len(tops), 1)))
        
        err = tops2-bots2
        
        Sigma_tops = np.diag(Sigma_Y)[I_indices_top]
        Sigma_bots = np.diag(Sigma_Y)[I_indices_bot]
        
        Sigma_tops2 = np.tile(Sigma_tops, (len(bots), 1)) # len(bots) length, len(tops) width
        Sigma_bots2 = np.transpose(np.tile(Sigma_bots, (len(tops), 1)))
        
        err = err / (Sigma_tops2 + Sigma_bots2) ** 0.5
        lst.append(np.max(abs(err)))
    
#         s = []
                                        
#         for i in range(len(rank_list)):
                                        
#             I = I_list[i]
#             I_indices = np.where(I == 1)[0]
            
#             s.append(np.max((abs(X_temp) / (np.diagonal(Sigma_Y) ** 0.5))[I_indices]))

    return np.quantile(np.array(lst), ab)

# %%
def c_2_quantile_asymmetric(ab, rank_list_top, rank_list_bottom, Sigma, delta_L, delta_U, n_iter, rand):

    ab_p = 1 - ab
    ab_p = ab_p / 2
    ab_p = 1 - ab_p
    
    lst_l = []
    lst_r = []

    Sigma_Y = Sigma

    for a in range(n_iter):
        print(a, end="")
        # print(i, end="")
        draw = rand.multivariate_normal(np.zeros(len(Sigma)), Sigma)
            
        X_temp = draw.copy()
        
        I_list_top = make_I_list(rank_list_top, X_temp, delta_L, delta_U)
        I_list_bot = make_I_list(rank_list_bottom, (-1 * X_temp), np.transpose(delta_L), np.transpose(delta_U))
        
        print()
        print(len(I_list_top))
        print(len(I_list_bot))
        
        I_indices_top = np.where(I_list_top == 1)[0]    
        I_indices_bot = np.where(I_list_bot == 1)[0]  

        tops = X_temp[I_indices_top]
        bots = X_temp[I_indices_bot]
        
        tops2 = np.tile(tops, (len(bots), 1)) # len(bots) length, len(tops) width
        bots2 = np.transpose(np.tile(bots, (len(tops), 1)))
        
        err = tops2-bots2
        
        Sigma_tops = np.diag(Sigma_Y)[I_indices_top]
        Sigma_bots = np.diag(Sigma_Y)[I_indices_bot]
        
        Sigma_tops2 = np.tile(Sigma_tops, (len(bots), 1)) # len(bots) length, len(tops) width
        Sigma_bots2 = np.transpose(np.tile(Sigma_bots, (len(tops), 1)))
        
        err = err / (Sigma_tops2 + Sigma_bots2) ** 0.5  
        
        lst_r.append(np.max(err))
        lst_l.append(np.min(err))

    return([np.quantile(-1 * np.array(lst_l), ab_p), np.quantile(np.array(lst_r), ab_p)])

# %%
def c_3_quantile(ab, subset, Sigma, n_iter, rand):
    
    lst = []
    N = len(Sigma)
    
    for i in range(n_iter):
        draw = rand.multivariate_normal(np.zeros(N), Sigma)
        
        draw = draw[subset]
        diag = np.diagonal(Sigma)[subset]
        lst.append(np.max(abs(draw / (diag ** (1/2)))))
            
    return np.quantile(np.array(lst), ab)

# %%
# Andrews et al. projection CI

def CI_proj(rank_list_top, rank_list_bot, y_vec, a, Sigma_Y, n_iter, quantile_dict, rand):

    th_hat_lst_top = [] 
    
    for i in range(len(rank_list_top)):
        th_hat_lst_top.append(np.argsort(y_vec)[len(y_vec)-rank_list_top[i]])
        
    th_hat_lst_bot = [] 
    
    for i in range(len(rank_list_bot)):
        th_hat_lst_bot.append(np.argsort(-1 * y_vec)[len(y_vec)-rank_list_bot[i]])
        
    try:
        c_a = quantile_dict[str(a) + str(Sigma_Y) + "c"]
    except:
        c_a = c_quantile(a, Sigma_Y, n_iter, rand = rand)
        quantile_dict[str(a) + str(Sigma_Y) + "c"] = c_a
        
    print(c_a)
        
    CI_list = []
    
    for i in range(len(rank_list_top)):
        for j in range(len(rank_list_bot)):
            th_hat_top = th_hat_lst_top[i]
            th_hat_bot = th_hat_lst_bot[j]
            
            CI_t = [(y_vec[th_hat_top] - y_vec[th_hat_bot]) - c_a * ((Sigma_Y[th_hat_top, th_hat_top] + Sigma_Y[th_hat_bot, th_hat_bot]) ** 0.5), (y_vec[th_hat_top] - y_vec[th_hat_bot]) + c_a * ((Sigma_Y[th_hat_top, th_hat_top] + Sigma_Y[th_hat_bot, th_hat_bot]) ** 0.5)]
            CI_list.append(CI_t)

    return CI_list

# %%
def two_step_CI(rank_list_top, rank_list_bot, y_vec, a, b, Sigma, n_iter, quantile_dict, rand):
    
    Sigma_Y = Sigma
    k = len(y_vec)

    th_hat_lst_top = [] 
    
    for i in range(len(rank_list_top)):
        th_hat_lst_top.append(np.argsort(y_vec)[len(y_vec)-rank_list_top[i]])
        
    th_hat_lst_bot = [] 
    
    for i in range(len(rank_list_bot)):
        th_hat_lst_bot.append(np.argsort(-1 * y_vec)[len(y_vec)-rank_list_bot[i]])
        
    print(y_vec[th_hat_lst_top])
    print(y_vec[th_hat_lst_bot])

    d = d_quantile(1 - b / 2, k, Sigma_Y, n_iter, rand = rand)
    print()
    
    l = np.tile(y_vec, (len(y_vec), 1))
    r = np.transpose(l)
    
    var_mat = np.tile(np.diag(Sigma_Y), (len(np.diag(Sigma_Y)), 1))
    var_mat += np.transpose(var_mat)
    var_mat -= 2 * Sigma_Y
    var_mat = var_mat ** 0.5
    
    L = r - l - d * var_mat
    U = r - l + d * var_mat
    
    # L[1,2] = r[1,2] - l[1,2] - d = l[2,1] - l[1,2] - d = y_vec[1] - y_vec[2] - d
    
    bd = c_2_quantile(1-a+b, rank_list_top, rank_list_bot, Sigma_Y, L, U, int(n_iter), rand = rand)
    print()
    print(bd)
    
    CI_list = []
    
    for i in range(len(rank_list_top)):
        for j in range(len(rank_list_bot)):
            th_hat_top = th_hat_lst_top[i]
            th_hat_bot = th_hat_lst_bot[j]
            
            CI_t = [(y_vec[th_hat_top] - y_vec[th_hat_bot]) - bd * ((Sigma_Y[th_hat_top, th_hat_top] + Sigma_Y[th_hat_bot, th_hat_bot]) ** 0.5), (y_vec[th_hat_top] - y_vec[th_hat_bot]) + bd * ((Sigma_Y[th_hat_top, th_hat_top] + Sigma_Y[th_hat_bot, th_hat_bot]) ** 0.5)]
            CI_list.append(CI_t)

    return CI_list

# %%
def two_step_CI_asymmetric(rank_list_top, rank_list_bot, y_vec, a, b, Sigma, n_iter, quantile_dict, rand):
    
    Sigma_Y = Sigma
    k = len(y_vec)

    th_hat_lst_top = [] 
    
    for i in range(len(rank_list_top)):
        th_hat_lst_top.append(np.argsort(y_vec)[len(y_vec)-rank_list_top[i]])
        
    th_hat_lst_bot = [] 
    
    for i in range(len(rank_list_bot)):
        th_hat_lst_bot.append(np.argsort(-1 * y_vec)[len(y_vec)-rank_list_bot[i]])

    d = d_quantile(1 - b / 2, k, Sigma_Y, n_iter, rand = rand)
    print()
    
    l = np.tile(y_vec, (len(y_vec), 1))
    r = np.transpose(l)
    
    var_mat = np.tile(np.diag(Sigma_Y), (len(np.diag(Sigma_Y)), 1))
    var_mat += np.transpose(var_mat)
    var_mat -= 2 * Sigma_Y
    var_mat = var_mat ** 0.5
    
    L = r - l - d * var_mat
    U = r - l + d * var_mat
    
    # L[1,2] = r[1,2] - l[1,2] - d = l[2,1] - l[1,2] - d = y_vec[1] - y_vec[2] - d
    
    bd = c_2_quantile_asymmetric(1 - a + b, rank_list_top, rank_list_bot, Sigma, L, U, int(n_iter), rand = rand)
    bd_l = bd[0]
    bd_r = bd[1]
    print()
    
    CI_list = []
    
    for i in range(len(rank_list_top)):
        for j in range(len(rank_list_bot)):
            th_hat_top = th_hat_lst_top[i]
            th_hat_bot = th_hat_lst_bot[j]
            
            CI_t = [(y_vec[th_hat_top] - y_vec[th_hat_bot]) - bd_r * ((Sigma_Y[th_hat_top, th_hat_top] + Sigma_Y[th_hat_bot, th_hat_bot]) ** 0.5), (y_vec[th_hat_top] - y_vec[th_hat_bot]) + bd_l * ((Sigma_Y[th_hat_top, th_hat_top] + Sigma_Y[th_hat_bot, th_hat_bot]) ** 0.5)]
            CI_list.append(CI_t)

    return CI_list

# %%
Sigma = pd.read_csv("Input_Data_CZs/Sigma_quantiles_neighborhood_CZs.csv",index_col = 0).to_numpy()
X = pd.read_csv("Input_Data_CZs/X_quantiles_neighborhood_CZs.csv",index_col = 0).to_numpy().flatten()
Y = np.array(pd.read_csv("Input_Data_CZs/Y_quantiles_neighborhood_CZs.csv",index_col = 0).to_numpy()).flatten()

# %%
rng = np.random.default_rng(42)

top_pairs = int(len(X) / 3)

print("Projection")
proj = pd.DataFrame(CI_proj([i for i in range(1,top_pairs)], [i for i in range(1,top_pairs)], X, 0.95, Sigma, 1000, {}, rng))

print("Two Step")
two_step = pd.DataFrame(two_step_CI([i for i in range(1,top_pairs)], [i for i in range(1,top_pairs)], X, 0.05, 0.005, Sigma, 1000, {}, rng))

#        [ 0.29003421,  0.54827394],
#        ...,
#        [-0.0308121 ,  0.12536211],
#        [-0.02558606,  0.11988901],
#        [-0.02093772,  0.1146386 ]])

# %%
proj = np.array(proj)
left = proj[:,0]

print(len(left[left < 0]) / len(left))

proj
# Out:
# 0.08341595611078062
# array([[ 0.31598874,  0.55000706],
#        [ 0.28790361,  0.5561344 ],
#        [ 0.28884235,  0.5494658 ],
#        ...,
#        [-0.0315329 ,  0.12608291],
#        [-0.02625747,  0.12056042],
#        [-0.02156345,  0.11526433]])

# %%
rng = np.random.default_rng(42)

top_pairs = int(len(X) / 5)

print("Projection")
proj = pd.DataFrame(CI_proj([i for i in range(1,top_pairs)], [i for i in range(1,top_pairs)], X, 0.95, Sigma, 1000, {}, rng))

print("Two Step")
two_step = pd.DataFrame(two_step_CI([i for i in range(1,top_pairs)], [i for i in range(1,top_pairs)], X, 0.05, 0.005, Sigma, 1000, {}, rng))

# print("Two Step")
# two_step_a = pd.DataFrame(two_step_CI_asymmetric([i for i in range(1,top_pairs)], [i for i in range(1,top_pairs)], X, 0.05, 0.005, Sigma, 1, {}, rng))
# Out:
# Projection
# 5.024093117853784
# Two Step
# [0.66626221 0.66572016 0.63084245 0.62131923 0.60789514 0.60572362
#  0.58837128 0.58801216 0.58705795 0.58590657 0.58036786 0.57991117
#  0.57923216 0.57913584 0.57553881 0.56807941 0.56752497 0.5657472
#  0.56487352 0.562998   0.56092602 0.55989242 0.5596723  0.55846167
#  0.55778074 0.55727744 0.554757   0.55371243 0.55365568 0.55049443
#  0.54947913 0.5494566  0.54866612 0.54849821 0.54837787 0.54752463
#  0.54567087 0.54515779 0.54196012 0.53929865 0.53875023 0.5384174
#  0.5366118  0.53592455 0.53456002 0.53392243 0.53360039 0.53342444
#  0.53304869 0.532736   0.53182739 0.53138649 0.52983904 0.52972507
#  0.52759331 0.52698785 0.52688056 0.52608073 0.52606326 0.5257718
#  0.52560705 0.52553535 0.52484131 0.52455878 0.52371258 0.52265579
#  0.52215475 0.5217182  0.52100903 0.51958799 0.5191015  0.51779264
#  0.51721311 0.51714063 0.51672453 0.51568621 0.51565647 0.51560783
#  0.51304454 0.51293391 0.51233673 0.51233119 0.51074243 0.51069856
#  0.51051158 0.50996596 0.50883836 0.50876868 0.50802952 0.50797695
#  0.50699586 0.50676656 0.50649214 0.50622755 0.50590253 0.50580299
#  0.50521803 0.505207   0.50271112 0.50265932 0.5011906  0.50078553
#  0.49952805 0.49807236 0.49646083 0.49620897 0.49538562 0.49400112
#  0.49311918 0.49310112 0.49275151 0.49128303 0.49101359 0.49084038
#  0.4898831  0.48987713 0.48938173 0.48847458 0.48787847 0.48570594
#  0.48538941 0.48527065 0.48457015 0.48409992 0.48403326 0.48353907
#  0.48302588 0.48292592 0.48214191 0.48142654 0.48111686 0.48084122
#  0.48029259 0.47989678 0.47931525 0.47917965 0.47901043 0.47866714
#  0.4780921  0.47794193 0.47756189 0.47741073 0.47729334 0.47715378
#  0.47711483 0.47694567 0.47685465]
# [0.23326431 0.2442432  0.24710813 0.28996751 0.30667362 0.32445639
#  0.32580534 0.32597768 0.32767841 0.33025992 0.3332915  0.33419344
#  0.33491996 0.3354471  0.33625588 0.33746758 0.3376072  0.33936301
#  0.33938536 0.33991903 0.34027302 0.3412199  0.34202397 0.34312737
#  0.34348848 0.3435007  0.3438344  0.34405756 0.34475291 0.34534889
#  0.34608006 0.34639466 0.3474417  0.34826723 0.34937087 0.34952793
#  0.34995732 0.35027465 0.35027516 0.35052887 0.3505663  0.3505798
#  0.35061547 0.35068363 0.35070416 0.35089958 0.35171974 0.35233435
#  0.35255003 0.35306188 0.35382697 0.35440123 0.35453838 0.35528949
#  0.35547766 0.35572052 0.35587183 0.35591859 0.35805768 0.35831201
#  0.3583861  0.35846871 0.3585453  0.35861295 0.35959524 0.36009762
#  0.3602719  0.3603237  0.36076534 0.3612006  0.36154455 0.36155891
#  0.36156523 0.36168918 0.36170879 0.36201453 0.36238307 0.3626096
#  0.36302051 0.36308008 0.36348888 0.3634896  0.36387184 0.36392024
#  0.36425951 0.36464089 0.3647559  0.36476186 0.3653115  0.36542726
#  0.3655659  0.36562887 0.36627126 0.36636043 0.3673375  0.36740074
#  0.36784509 0.36806241 0.36820522 0.36826134 0.36832771 0.36892179
#  0.36892325 0.36971372 0.36985236 0.3701936  0.37025383 0.37049353
#  0.37082943 0.37090024 0.37169015 0.37180752 0.37208951 0.37214822
#  0.37252715 0.37270483 0.37276009 0.37341398 0.37366968 0.37405634
#  0.37414894 0.37433586 0.37436506 0.37441453 0.37457645 0.37500048
#  0.37543991 0.37613487 0.37664062 0.37709114 0.37725991 0.37731031
#  0.37738457 0.37747043 0.3776083  0.37779117 0.37787393 0.37798658
#  0.37804106 0.37838882 0.37841746 0.37869695 0.37880698 0.37914118
#  0.37954086 0.37992665 0.38031283]
#
# 741
# 0
# 342
# 318
# 1
# 358
# 316
# 2
# 344
# 319
# 3
# 347
# 320
# 4
# 365
# 317
# 5
# 349
# 321
# 6
# 355
# 319
# 7
# 354
# 319
# 8
# 354
# 333
# 9
# 349
# 322
# 10
# 344
# 328
# 11
# 358
# 319
# 12
# 352
# 318
# 13
# 353
# 319
# 14
# 355
# 326
# 15
# 352
# 319
# 16
# 359
# 327
# 17
# 350
# 320
# 18
# 353
# 326
# 19
# 352
# 313
# 20
# 359
# 320
# 21
# 352
# 318
# 22
# 350
# 318
# 23
# 347
# 319
# 24
# 354
# 310
# 25
# 352
# 315
# 26
# 353
# 324
# 27
# 347
# 333
# 28
# 345
# 321
# 29
# 354
# 324
# 30
# 354
# 318
# 31
# 355
# 326
# 32
# 347
# 316
# 33
# 353
# 329
# 34
# 348
# 318
# 35
# 344
# 322
# 36
# 354
# 315
# 37
# 353
# 312
# 38
# 346
# 321
# 39
# 351
# 318
# 40
# 350
# 333
# 41
# 350
# 326
# 42
# 358
# 323
# 43
# 349
# 321
# 44
# 351
# 313
# 45
# 346
# 317
# 46
# 357
# 325
# 47
# 352
# 324
# 48
# 345
# 319
# 49
# 347
# 322
# 50
# 350
# 316
# 51
# 355
# 353
# 323
# 950
# 353
# 314
# 951
# 350
# 316
# 952
# 343
# 320
# 953
# 349
# 324
# 954
# 345
# 319
# 955
# 345
# 317
# 956
# 356
# 326
# 957
# 343
# 316
# 958
# 343
# 320
# 959
# 354
# 320
# 960
# 349
# 333
# 961
# 351
# 324
# 962
# 355
# 319
# 963
# 356
# 336
# 964
# 344
# 323
# 965
# 343
# 319
# 966
# 359
# 316
# 967
# 354
# 323
# 968
# 353
# 322
# 969
# 360
# 319
# 970
# 356
# 319
# 971
# 356
# 320
# 972
# 355
# 318
# 973
# 347
# 326
# 974
# 357
# 321
# 975
# 351
# 323
# 976
# 344
# 325
# 977
# 347
# 320
# 978
# 354
# 328
# 979
# 354
# 325
# 980
# 352
# 321
# 981
# 353
# 334
# 982
# 350
# 328
# 983
# 346
# 325
# 984
# 354
# 319
# 985
# 343
# 329
# 986
# 347
# 323
# 987
# 353
# 318
# 988
# 352
# 324
# 989
# 350
# 319
# 990
# 356
# 320
# 991
# 349
# 325
# 992
# 348
# 325
# 993
# 351
# 325
# 994
# 352
# 340
# 995
# 351
# 325
# 996
# 359
# 332
# 997
# 351
# 321
# 998
# 340
# 320
# 999
# 347
# 319
#
# 4.802720928392608

# %%
two_step = np.array(two_step)
left = two_step[:,0]

print(len(left[left < 0]) / len(left))
print(len(left[left < 0]))

two_step
# Out:
# 0.04673978434911379
# 1010
# array([[0.32114441, 0.54485139],
#        [0.29381301, 0.550225  ],
#        [0.29458416, 0.54372399],
#        ...,
#        [0.06401933, 0.13060826],
#        [0.06802687, 0.12582914],
#        [0.06961084, 0.12347281]])

# %%
proj = np.array(proj)
left = proj[:,0]

print(len(left[left < 0]) / len(left))
print(len(left[left < 0]))

proj
# Out:
# 0.05321856633809986
# 1150
# array([[0.31598874, 0.55000706],
#        [0.28790361, 0.5561344 ],
#        [0.28884235, 0.5494658 ],
#        ...,
#        [0.06248468, 0.1321429 ],
#        [0.06669472, 0.12716128],
#        [0.0683695 , 0.12471414]])

# %%
rng = np.random.default_rng(42)

top_pairs = int(len(X) / 2)

print("Projection")
proj = pd.DataFrame(CI_proj([i for i in range(1,top_pairs)], [i for i in range(1,top_pairs)], X, 0.95, Sigma, 1000, {}, rng))

print("Two Step")
two_step = pd.DataFrame(two_step_CI([i for i in range(1,top_pairs)], [i for i in range(1,top_pairs)], X, 0.05, 0.005, Sigma, 1000, {}, rng))

# print("Two Step")
# two_step_a = pd.DataFrame(two_step_CI_asymmetric([i for i in range(1,top_pairs)], [i for i in range(1,top_pairs)], X, 0.05, 0.005, Sigma, 1, {}, rng))

# %%
two_step = np.array(two_step)
left = two_step[:,0]

print(len(left[left < 0]) / len(left))
print(len(left[left < 0]))

two_step

# %%
proj = np.array(proj)
left = proj[:,0]

print(len(left[left < 0]) / len(left))
print(len(left[left < 0]))

proj

# %%
rng = np.random.default_rng(42)

top_pairs = int(len(X) / 5)

print("Projection")
proj = pd.DataFrame(CI_proj([i for i in range(1,top_pairs)], [1], X, 0.95, Sigma, 1000, {}, rng))

print("Two Step")
two_step = pd.DataFrame(two_step_CI([i for i in range(1,top_pairs)], [1], X, 0.05, 0.005, Sigma, 1000, {}, rng))

# print("Two Step")
# two_step_a = pd.DataFrame(two_step_CI_asymmetric([i for i in range(1,top_pairs)], [1], X, 0.05, 0.005, Sigma, 10000, {}, rng))
# Out:
# Projection
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 16, in CI_proj(rank_list_top, rank_list_bot, y_vec, a, Sigma_Y, n_iter, quantile_dict, rand)
#      15 try:
# ---> 16     c_a = quantile_dict[str(a) + str(Sigma_Y) + "c"]
#      17 except:
#
# KeyError: '0.95[[2.93798561e-06 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00\n  0.00000000e+00 0.00000000e+00]\n [0.00000000e+00 5.65942033e-06 0.00000000e+00 ... 0.00000000e+00\n  0.00000000e+00 0.00000000e+00]\n [0.00000000e+00 0.00000000e+00 1.86217008e-05 ... 0.00000000e+00\n  0.00000000e+00 0.00000000e+00]\n ...\n [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.38391443e-05\n  0.00000000e+00 0.00000000e+00]\n [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00\n  2.36631600e-05 0.00000000e+00]\n [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00\n  0.00000000e+00 8.14662390e-07]]c'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 6
#       3 top_pairs = int(len(X) / 5)
#       5 print("Projection")
# ----> 6 proj = pd.DataFrame(CI_proj([i for i in range(1,top_pairs)], [1], X, 0.95, Sigma, 1000, {}, rng))
#       8 print("Two Step")
#       9 two_step = pd.DataFrame(two_step_CI([i for i in range(1,top_pairs)], [1], X, 0.05, 0.005, Sigma, 1000, {}, rng))
#
# Cell In[10], line 18, in CI_proj(rank_list_top, rank_list_bot, y_vec, a, Sigma_Y, n_iter, quantile_dict, rand)
#      16     c_a = quantile_dict[str(a) + str(Sigma_Y) + "c"]
#      17 except:
# ---> 18     c_a = c_quantile(a, Sigma_Y, n_iter, rand = rand)
#      19     quantile_dict[str(a) + str(Sigma_Y) + "c"] = c_a
#      21 print(c_a)
#
# Cell In[2], line 18, in c_quantile(a, Sigma_Y, n_iter, rand)
#      16     for row in range(len(draw)):
#      17         for col in range(len(draw)):
# ---> 18             comps.append(abs(draw[row] - draw[col]) / (Sigma_Y[row, row] + Sigma_Y[col,col]) ** 0.5)
#      20     lst.append(np.max(np.array(comps)))
#      22 return np.quantile(np.array(lst), a)
#
# KeyboardInterrupt:

# %%
two_step = np.array(two_step)
left = two_step[:,0]

len(left[left < 0]) / len(left)

two_step

# %%
proj = np.array(proj)
left = proj[:,0]

print(len(left[left < 0]) / len(left))

proj

# %%
pd.DataFrame(proj).to_csv("Urban_CIs/CI_Seattle_pairs_proj.csv")

pd.DataFrame(two_step).to_csv("Urban_CIs/CI_Seattle_pairs_two_step.csv")

# %%
rng = np.random.default_rng(42)

top_pairs = int(len(X) / 5)

print("Projection")
proj = pd.DataFrame(CI_proj([1], [1], X, 0.95, Sigma, 1000, {}, rng))

print("Two Step")
two_step = pd.DataFrame(two_step_CI([1], [1], X, 0.05, 0.005, Sigma, 1000, {}, rng))

print("Two Step")
two_step_a = pd.DataFrame(two_step_CI_asymmetric([1], [1], X, 0.05, 0.005, Sigma, 1000, {}, rng))

# %%
two_step

# %%
proj
